# %% [markdown]
# # Notebook Synopsis:
#     -How to load labels & memory requirements
#     -How to load inputs & memory requirements
#     -How to print modalities for a slice in a patient

# %% [markdown]
# ## Note: this notebook only works if run in the S20-team0-project. Placed in examples dir for reference

# %%
from utils.hgg_utils import *
import matplotlib.pyplot as plt
import sys
# %matplotlib inline

# %% [markdown]
# # Load labels/masks

# %%
Y = get_all_mask_volumes()

# %%
Y.shape
# Out:
# (259, 240, 240, 155, 1)

# %% [markdown]
# ### Labels take up ~ 9 GB of memory

# %%
sys.getsizeof(Y) / 1e9
# Out:
# 9.24940816

# %% [markdown]
# # Load inputs

# %%
X = get_all_input_volumes()

# %%
X.shape
# Out:
# (259, 240, 240, 155, 4)

# %% [markdown]
# ### Inputs take up ~ 37 GB of memory

# %%
sys.getsizeof(X) / 1e9
# Out:
# 36.99763216

# %% [markdown]
# # Look at modalities of slice 70 for patient 20

# %%
print_multimodal_slice(X, patient_idx=20, slice_idx=70)
