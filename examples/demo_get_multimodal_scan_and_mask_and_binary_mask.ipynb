# %% [markdown]
# # Notebook Synopsis:
#     - Get a multimodal tensor for a patient
#     - Get the corresponding mask tensor for the patient
#     - Covert the mask tensor into a binary mask tensor

# %% [markdown]
# # Note: this notebook must be run in S20-team0-project dir to work correctly. Placed in examples for reference

# %%
import tensorflow as tf
import utils.hgg_utils as hu
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
patient = hu.get_each_hgg_folder()[0]

# %% [markdown]
# # Get a multimodal tensor

# %%
X_0 = hu.get_a_multimodal_tensor( patient )

# %%
X_0.shape
# Out:
# (240, 240, 155, 4)

# %% [markdown]
# # Look at slice 70 on the different modalities in the multimodal tensor

# %% [markdown]
# #### Flair

# %%
plt.imshow(X_0[:,:,70,0].T, cmap="Greys_r")

# %% [markdown]
# #### t1

# %%
plt.imshow(X_0[:,:,70,1].T, cmap="Greys_r")

# %% [markdown]
# #### t1ce

# %%
plt.imshow(X_0[:,:,70,2].T, cmap="Greys_r")

# %% [markdown]
# #### t2

# %%
plt.imshow(X_0[:,:,70,3].T, cmap="Greys_r")

# %% [markdown]
# # Get its mask tensor

# %%
mask = hu.get_a_mask_tensor(patient)

# %%
mask.shape
# Out:
# (240, 240, 155, 1)

# %% [markdown]
# # Look at slice 70 in the mask

# %%
plt.imshow(mask[:,:,70,0].T, cmap="Greys_r")

# %% [markdown]
# # Convert mask to binary mask

# %%
bin_mask = hu.convert_mask_to_binary_mask( mask )

# %% [markdown]
# # Look at slice 70 in the binary mask

# %%
plt.imshow(bin_mask[:,:,70,0].T, cmap="Greys_r")
