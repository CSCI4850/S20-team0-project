# %% [markdown]
# # List the Python packages already on the docker image

# %%
# !pip list
# Out:
# Package                Version
# ---------------------- ----------------------------
# absl-py                0.9.0
# alembic                1.3.1
# astor                  0.7.1
# async-generator        1.10
# attrs                  19.3.0
# backcall               0.1.0
# bash-kernel            0.7.2
# beautifulsoup4         4.8.1
# bleach                 3.1.0
# blinker                1.4
# bokeh                  1.3.4
# boto                   2.49.0
# boto3                  1.11.9
# botocore               1.14.9
# certifi                2019.11.28
# certipy                0.1.3
# cffi                   1.13.2
# chardet                3.0.4
# Click                  7.0
# cloudpickle            1.2.2
# conda                  4.7.12
# conda-package-handling 1.6.0
# cryptography           2.8
# cycler                 0.10.0
# Cython                 0.29.14
# cytoolz                0.10.1
# dask                   2.2.0
# decorator              4.4.1
# defusedxml             0.6.0
# ...

# %% [markdown]
# # Note: nibabel is not present

# %% [markdown]
# # We can easily and quickly install nibabel with the following command

# %%
# !pip install nibabel
# Out:
# ...
#      |████████████████████████████████| 3.3MB 1.4MB/s eta 0:00:01     |████▎                           | 440kB 1.4MB/s eta 0:00:02     |███████████                     | 1.1MB 1.4MB/s eta 0:00:02
# ...

# %% [markdown]
# # Now we can see nibabel is installed

# %% [markdown]
# # Note: this may need to be done each time you reconnect to the docker image.
# # For future: a script should be written and run every time someone uses the docker image to install all dependecies we decide upon

# %%
# !pip list
# Out:
# Package                Version
# ---------------------- ----------------------------
# absl-py                0.9.0
# alembic                1.3.1
# astor                  0.7.1
# async-generator        1.10
# attrs                  19.3.0
# backcall               0.1.0
# bash-kernel            0.7.2
# beautifulsoup4         4.8.1
# bleach                 3.1.0
# blinker                1.4
# bokeh                  1.3.4
# boto                   2.49.0
# boto3                  1.11.9
# botocore               1.14.9
# certifi                2019.11.28
# certipy                0.1.3
# cffi                   1.13.2
# chardet                3.0.4
# Click                  7.0
# cloudpickle            1.2.2
# conda                  4.7.12
# conda-package-handling 1.6.0
# cryptography           2.8
# cycler                 0.10.0
# Cython                 0.29.14
# cytoolz                0.10.1
# dask                   2.2.0
# decorator              4.4.1
# defusedxml             0.6.0
# ...
